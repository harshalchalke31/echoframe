# %%
from dataloader import EchoMasks
import torch
from utils import visualize_segmentation_masks,visualize_segmentation_masks_with_background
import pandas as pd
import cv2

# %% [markdown]
# ## Pediatric dataset

# %%
video_name = "CR3dca6a0-CR3dca87f-000033.avi"
video_path = "./data/pediatric_echo_avi/A4C/Videos"
filelist_path = "./data/pediatric_echo_avi/A4C/FileList.csv"
volume_tracings_path = "./data/pediatric_echo_avi/A4C/VolumeTracings.csv"

visualize_segmentation_masks(video_name=video_name,video_folder=video_path,filelist_path=filelist_path,tracings_path=volume_tracings_path)

# %%
visualize_segmentation_masks_with_background(video_name=video_name,video_folder=video_path,filelist_path=filelist_path,tracings_path=volume_tracings_path)

# %%
cap = cv2.VideoCapture('./data/pediatric_echo_avi/A4C/Videos/CR3dca6a0-CR3dca87f-000033.avi')
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
tracings_df = pd.read_csv(volume_tracings_path)
video_tracings = tracings_df[tracings_df['FileName'] == video_name]
print(frame_count,video_tracings.shape)
# Out:
# 58 (27, 4)

# %% [markdown]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# /home/hc4293/miniconda3/envs/imgsenv2/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/steps/step - accuracy: 0.9744 - loss: 0.0740
# 7460/7460 ━━━━━━━━━━━━━━━━━━━━ 309s 38ms/step - accuracy: 0.9744 - loss: 0.0740 - val_accuracy: 0.9846 - val_loss: 0.0379
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/steps/step - accuracy: 0.9855 - loss: 0.0361
# 7460/7460 ━━━━━━━━━━━━━━━━━━━━ 212s 28ms/step - accuracy: 0.9855 - loss: 0.0361 - val_accuracy: 0.9844 - val_loss: 0.0384
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/steps/step - accuracy: 0.9870 - loss: 0.0314
# 7460/7460 ━━━━━━━━━━━━━━━━━━━━ 217s 29ms/step - accuracy: 0.9870 - loss: 0.0314 - val_accuracy: 0.9865 - val_loss: 0.0330
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/steps/step - accuracy: 0.9877 - loss: 0.0295
# 7460/7460 ━━━━━━━━━━━━━━━━━━━━ 227s 30ms/step - accuracy: 0.9877 - loss: 0.0295 - val_accuracy: 0.9858 - val_loss: 0.0373
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/steps/step - accuracy: 0.9880 - loss: 0.0284
# 7460/7460 ━━━━━━━━━━━━━━━━━━━━ 225s 30ms/step - accuracy: 0.9880 - loss: 0.0284 - val_accuracy: 0.9860 - val_loss: 0.0360
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/steps/step - accuracy: 0.9885 - loss: 0.0269
# 7460/7460 ━━━━━━━━━━━━━━━━━━━━ 223s 30ms/step - accuracy: 0.9885 - loss: 0.0269 - val_accuracy: 0.9865 - val_loss: 0.0345
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/steps/step - accuracy: 0.9887 - loss: 0.0262
# 7460/7460 ━━━━━━━━━━━━━━━━━━━━ 241s 32ms/step - accuracy: 0.9887 - loss: 0.0262 - val_accuracy: 0.9866 - val_loss: 0.0356
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/steps/step - accuracy: 0.9888 - loss: 0.0260
# 7460/7460 ━━━━━━━━━━━━━━━━━━━━ 242s 32ms/step - accuracy: 0.9888 - loss: 0.0260 - val_accuracy: 0.9875 - val_loss: 0.0345
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/steps/step - accuracy: 0.9893 - loss: 0.0248
# 7460/7460 ━━━━━━━━━━━━━━━━━━━━ 248s 33ms/step - accuracy: 0.9893 - loss: 0.0248 - val_accuracy: 0.9873 - val_loss: 0.0339
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/steps/step - accuracy: 0.9894 - loss: 0.0243
# 7460/7460 ━━━━━━━━━━━━━━━━━━━━ 239s 32ms/step - accuracy: 0.9894 - loss: 0.0243 - val_accuracy: 0.9869 - val_loss: 0.0359

# %% [markdown]
# ## Adults dataset

# %%
video_name = "0X100009310A3BD7FC.avi"
video_path = "/home/hc4293/echoframe/data/echodynamic/Videos"
filelist_path = "/home/hc4293/echoframe/data/echodynamic/FileList.csv"
volume_tracings_path = "/home/hc4293/echoframe/data/echodynamic/VolumeTracings.csv"

# %%
visualize_segmentation_for_adults(video_name,video_folder=video_path,filelist_path=filelist_path,tracings_path=volume_tracings_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 visualize_segmentation_for_adults(video_name,video_folder=video_path,filelist_path=filelist_path,tracings_path=volume_tracings_path)
#
# NameError: name 'visualize_segmentation_for_adults' is not defined
